# %%
import os
from dotenv import load_dotenv
import cv2
load_dotenv()
URI = os.getenv('DB_URI')
COSIN = os.getenv('COSIN_INDEX')
EUCLIDEAN = os.getenv('EUCLIDEAN_INDEX')
DOT_PRODUCT = os.getenv('DOT_PRODUCT_INDEX')
SEARCH_FIELD = os.getenv('SEARCH_FIELD')

print(f"{URI}\n{COSIN}\n{EUCLIDEAN}\n{DOT_PRODUCT}\n{SEARCH_FIELD}")
# Out:
# 2024-10-22 22:19:01.029168: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-22 22:19:01.082622: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-22 22:19:01.098410: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-22 22:19:01.132870: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-22 22:19:02.911346: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# mongodb+srv://adityavinchhi210480:wGUg2LWDXSaCTLIc@cluster0.7i5qa.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
# Face_search_cosine
# Face_search_euclidean
# Face_search_dotproduct
# embedding

# %%
from utils.db import PersonCollection
from utils.encoder import Encoder

person = PersonCollection(URI)
ecd = Encoder()

# %% [markdown]
# ## Search with Embedding

# %%
img = cv2.imread('Trash/8.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# embed
embeddings = ecd.encode(img)

result = person.search(
    embeddings[0], 
    index_name=COSIN, 
    field=SEARCH_FIELD
)

result
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# embedding: [0.4719473421573639, 0.03675629198551178, 0.0, 0.7332517504692078, 0.0, 0.0, 2.091615676879883, 0.63125079870224, 0.16818645596504211, 0.24011197686195374, 3.7331113815307617, 2.0589046478271484, 0.35729163885116577, 2.413299798965454, 0.0, 0.1849271059036255, 0.22386246919631958, 1.3764170408248901, 2.7149569988250732, 0.0056391931138932705, 0.12598086893558502, 0.8600557446479797, 1.4297209978103638, 2.9891741275787354, 0.010610395111143589, 0.0006438955897465348, 1.600937843322754, 1.7583507299423218, 0.10523354262113571, 0.0, 0.006436868570744991, 1.9967892169952393, 0.0, 0.16055046021938324, 1.0136414766311646, 0.10376955568790436, 0.3118654489517212, 1.0618277788162231, 0.44371747970581055, 0.0, 0.3918803334236145, 0.04268161207437515, 0.597032368183136, 0.6192700862884521, 1.5860258340835571, 0.0, 0.599679172039032, 0.16690745949745178, 0.8039178848266602, 0.06260299682617188, 0.014940203167498112, 0.0, 0.18975745141506195, 0.28208282589912415, 0.6120467782020569, 0.21804213523864746, 0.0, 1.3583306074142456, 0.0, 0.06725316494703293, 0.12147219479084015, 0.07939151674509048, 1.8136061429977417, 1.2007005214691162, 2.6195971965789795, 0.5643354058265686, 0.8502561450004578, 1.7731531858444214, 0.6431311964988708, 0.5207675099372864, 0.23375079035758972, 1.038893461227417, 1.5752090215682983, 0.2952493131160736, 0.0, 0.4915485382080078, 0.2198857218027115, 0.018670568242669106, 0.24188333749771118, 0.0, 0.009938211180269718, 1.0297572612762451, 0.0, 0.6264470219612122, 0.0, 0.04059329628944397, 0.3003806471824646, 0.6985595226287842, 0.0779481828212738, 2.072584867477417, 3.2502076625823975, 0.15117695927619934, 0.06125767529010773, 0.03899940103292465, 0.6911560297012329, 0.8348780870437622, 0.09748182445764542, 0.0, 0.28633373975753784, 0.0, 0.35598117113113403, 0.0581633597612381, 0.5967434644699097, 0.0, 3.394110918045044, 0.0, 0.0, 0.0, 1.7725971937179565, 0.21053217351436615, 0.03945622965693474, 0.1905464082956314, 0.0, 0.19776375591754913, 1.6793431043624878, 0.013919713906943798, 0.40909984707832336, 0.14151206612586975, 0.7151575088500977, 0.11741743236780167, 0.02815609611570835, 0.5523236393928528, 0.1405949741601944, 3.176281690597534, 2.415783405303955, 0.0367085337638855, 0.17270247638225555, 0.6710535287857056, 0.010204490274190903, 0.07802069932222366, 1.810462474822998, 0.4158356189727783, 0.23588627576828003, 0.8013463020324707, 0.0, 1.971475601196289, 0.29210057854652405, 3.5592739582061768, 0.0, 0.8742269277572632, 0.0, 1.374407410621643, 0.024412641301751137, 0.18834178149700165, 0.12811113893985748, 0.0, 0.2807435691356659, 0.0009326910367235541, 0.0, 0.9204684495925903, 0.030361700803041458, 1.9397399425506592, 0.014642024412751198, 0.36871933937072754, 3.320620059967041, 2.218489408493042, 0.410204142332077, 0.19128021597862244, 0.5941765308380127, 0.3238791823387146, 1.6377127170562744, 0.06337808072566986, 0.010238763876259327, 0.07367122918367386, 0.21029409766197205, 0.19850395619869232, 0.6014335751533508, 0.5193312764167786, 0.19134540855884552, 1.0895496606826782, 0.18530258536338806, 0.10610488802194595, 0.0, 2.4542133808135986, 0.04961313679814339, 0.5848384499549866, 0.4352121949195862, 2.9543585777282715, 0.3272744119167328, 0.11515436321496964, 0.7323237657546997, 0.09704767167568207, 0.0, 0.007483482360839844, 0.72954922914505, 0.07384161651134491, 1.672019362449646, 0.6652876138687134, 0.041144389659166336, 0.8969544172286987, 0.1257600039243698, 0.0, 0.0, 0.49673593044281006, 2.1526339054107666, 0.15918295085430145, 0.0, 0.30911314487457275, 0.06337970495223999, 0.2863818109035492, 1.252577781677246, 0.12651801109313965, 0.0, 2.452575445175171, 0.7828220725059509, 0.7998084425926208, 0.8631465435028076, 1.2986609935760498, 0.5308319330215454, 0.14007407426834106, 0.8300190567970276, 0.9138694405555725, 0.17250575125217438, 0.03371509164571762, 1.0094026327133179, 0.0, 0.31427228450775146, 0.4776208698749542, 1.2048522233963013, 0.5978530049324036, 0.5790644884109497, 0.9 ...
# index_name: Face_search_cosine
# field: embedding
# [{'_id': ObjectId('67179fa4dc92bf3c93f89cc4'),
#   'name': 'Mike Tyson',
#   'student_id': '0827CS211002',
#   'search_score': 0.7944759726524353},
#  {'_id': ObjectId('67179fa4dc92bf3c93f89cc6'),
#   'name': 'Jay Malvani',
#   'student_id': '0827CS211004',
#   'search_score': 0.7941886782646179},
#  {'_id': ObjectId('67179fa4dc92bf3c93f89cc8'),
#   'name': 'Aditya',
#   'student_id': '0827CS211006',
#   'search_score': 0.7938874959945679},
#  {'_id': ObjectId('67179fa4dc92bf3c93f89cc7'),
#   'name': 'Ajay Mungi',
#   'student_id': '0827CS211005',
#   'search_score': 0.7830755710601807}]

# %% [markdown]
# ## Add embedding of a person

# %%
dua_img = cv2.imread('images/Train/1.jpg')
dua_img = cv2.cvtColor(dua_img, cv2.COLOR_BGR2RGB)

embeddings = ecd.encode(dua_img)

person_data = {
    "name": "Dua Lipa",
    "student_id": "0827CS211001",
    "embedding": embeddings[0]
}
res = person.add_person(person_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
